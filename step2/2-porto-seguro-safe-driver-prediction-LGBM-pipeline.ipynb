# %%
# Set the folder for the experiment files used in Challenge 2
training_folder = 'driver-training'

# %% [markdown]
# ## register_model.py
# This script loads the model from where it was saved, and then registers it in the workspace. This will be the second step in the pipeline. The script is written to the experiment folder from this notebook for convenience.

# %%
# %%writefile $training_folder/register_model.py
# Import libraries
import argparse
from azureml.core import Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder',
                    default="driver-training", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_name = 'porto_seguro_safe_driver_model'
model_file = model_folder + "/" + model_name + ".pkl"

# Get metrics for registration
metrics = run.parent.get_metrics()
## HINT: Try storing the metrics in the parent run, which will be
##       accessible during both the training and registration
##       child runs using the 'run.parent' API.

# Register the model
run.upload_file(model_name, model_file)
run.register_model(
    model_path=model_name,
    model_name=model_name,
    tags=metrics)

run.complete()
# Out:
# Overwriting driver-training/register_model.py

# %% [markdown]
# ## Create an Azure Machine Learning Pipeline to Run the Scripts as a Pipeline
#
# See [this tutorial](https://github.com/MicrosoftDocs/mslearn-aml-labs/blob/master/05-Creating_a_Pipeline.ipynb) for a starting point
#
# Use the scikit-learn and lightgbm conda packages

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace
ws = Workspace.from_config()
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (portalocker 2.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('portalocker~=1.0'), {'msal-extensions'}).

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "mlops-cc"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
driver_env = Environment("driver-pipeline-env")
driver_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
driver_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
driver_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas', 'lightgbm'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]'])

# Add the dependencies to the environment
driver_env.python.conda_dependencies = driver_packages

# Register the environment (just in case you want to use it again)
driver_env.register(workspace=ws)
registered_env = Environment.get(ws, 'driver-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
driver_ds = ws.datasets.get("driver dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

# Create Estimator to train the model as in Challenge 2
estimator = Estimator(source_directory=training_folder,
                      entry_script='driver_training.py',
                      compute_target=pipeline_cluster,
                      environment_definition=pipeline_run_config.environment)

# Create Step 1, which runs the estimator to train the model
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[driver_ds.as_named_input('driver_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Create Step 2, which runs the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = training_folder,
                                script_name = "register_model.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)
print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'driver-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Train Model [743c947f][26dc8131-f09f-4352-a1f4-178976a9b395], (This step will run and generate new outputs)
# Created step Register Model [7928f698][a7575e1b-ceb9-4d54-9fad-5bd20798b744], (This step will run and generate new outputs)
# Submitted PipelineRun c25e809f-4b13-43b4-ac4e-2fad95ecbf79
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/c25e809f-4b13-43b4-ac4e-2fad95ecbf79?wsid=/subscriptions/7c9d382c-5964-48db-9cf6-c595c7ba4339/resourcegroups/mlops-rg/workspaces/mlops-aml
# Pipeline submitted for execution.
# PipelineRunId: c25e809f-4b13-43b4-ac4e-2fad95ecbf79
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/c25e809f-4b13-43b4-ac4e-2fad95ecbf79?wsid=/subscriptions/7c9d382c-5964-48db-9cf6-c595c7ba4339/resourcegroups/mlops-rg/workspaces/mlops-aml
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: c4ad3808-73c9-431d-b90d-99cf99e66e67
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/c4ad3808-73c9-431d-b90d-99cf99e66e67?wsid=/subscriptions/7c9d382c-5964-48db-9cf6-c595c7ba4339/resourcegroups/mlops-rg/workspaces/mlops-aml
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# ========================================================================================================================
# 2020-08-28T20:34:44Z Starting output-watcher...
# 2020-08-28T20:34:44Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-28T20:34:45Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-08-28T20:34:45Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_30cd9c75f2bacedf66a964559d217bc8
# 6aa38bd67045: Pulling fs layer
# 981ae4862c05: Pulling fs layer
# 5bad8949dcb1: Pulling fs layer
# ca9461589e70: Pulling fs layer
# 98d7f5a52dc7: Pulling fs layer
# 55bd0fd3d326: Pulling fs layer
# c701d81a8c64: Pulling fs layer
# 377536e3f3d3: Pulling fs layer
# be7af55ccd20: Pulling fs layer
# 527ddc9414f3: Pulling fs layer
# 67e3aa572370: Pulling fs layer
# 41d293c79c2d: Pulling fs layer
# 3b3e5d222c2f: Pulling fs layer
# 62fef4d757cc: Pulling fs layer
# 8a42f4955cf6: Pulling fs layer
# 935d8a7eb423: Pulling fs layer
# e3925acaecfb: Pulling fs layer
# a2595730c629: Pulling fs layer
# 527ddc9414f3: Waiting
# 67e3aa572370: Waiting
# 41d293c79c2d: Waiting
# 3b3e5d222c2f: Waiting
# 62fef4d757cc: Waiting
# 8a42f4955cf6: Waiting
# 935d8a7eb423: Waiting
# e3925acaecfb: Waiting
# a2595730c629: Waiting
# ca9461589e70: Waiting
# 98d7f5a52dc7: Waiting
# 55bd0fd3d326: Waiting
# c701d81a8c64: Waiting
# 377536e3f3d3: Waiting
# be7af55ccd20: Waiting
# 981ae4862c05: Verifying Checksum
# 981ae4862c05: Download complete
# 5bad8949dcb1: Verifying Checksum
# 5bad8949dcb1: Download complete
# 6aa38bd67045: Verifying Checksum
# 6aa38bd67045: Download complete
# ca9461589e70: Verifying Checksum
# ca9461589e70: Download complete
# 55bd0fd3d326: Verifying Checksum
# 55bd0fd3d326: Download complete
# 98d7f5a52dc7: Verifying Checksum
# 98d7f5a52dc7: Download complete
# c701d81a8c64: Verifying Checksum
# c701d81a8c64: Download complete
# 527ddc9414f3: Verifying Checksum
# 527ddc9414f3: Download complete
# 377536e3f3d3: Verifying Checksum
# 377536e3f3d3: Download complete
# 41d293c79c2d: Verifying Checksum
# 41d293c79c2d: Download complete
# 67e3aa572370: Verifying Checksum
# 67e3aa572370: Download complete
# 62fef4d757cc: Verifying Checksum
# 62fef4d757cc: Download complete
# 6aa38bd67045: Pull complete
# be7af55ccd20: Verifying Checksum
# be7af55ccd20: Download complete
# 981ae4862c05: Pull complete
# 3b3e5d222c2f: Verifying Checksum
# 3b3e5d222c2f: Download complete
# 5bad8949dcb1: Pull complete
# 935d8a7eb423: Download complete
# 8a42f4955cf6: Verifying Checksum
# 8a42f4955cf6: Download complete
# ca9461589e70: Pull complete
# a2595730c629: Verifying Checksum
# a2595730c629: Download complete
# e3925acaecfb: Verifying Checksum
# e3925acaecfb: Download complete
# 98d7f5a52dc7: Pull complete
# 55bd0fd3d326: Pull complete
# c701d81a8c64: Pull complete
# 377536e3f3d3: Pull complete
# be7af55ccd20: Pull complete
# 527ddc9414f3: Pull complete
# 67e3aa572370: Pull complete
# 41d293c79c2d: Pull complete
# 3b3e5d222c2f: Pull complete
# 62fef4d757cc: Pull complete
# 8a42f4955cf6: Pull complete
# 935d8a7eb423: Pull complete
# e3925acaecfb: Pull complete
# a2595730c629: Pull complete
# Digest: sha256:87695151d6316cd952b7e7698fbf52e744815249da724ceb53bc83ae049f7416
# Status: Downloaded newer image for f3a8797ad922485389fee8fb528d6fce.azurecr.io/azureml/azureml_30cd9c75f2bacedf66a964559d217bc8:latest
# d953d257a45d5818d42ece99da5a4fbc28c5652205bf28ac4a2bdb9119852010
# 2020/08/28 20:36:17 setuptask.go:353: Starting App Insight Logger for task:  containerSetup
# 2020/08/28 20:36:17 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# 2020/08/28 20:36:17 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/28 20:36:17 logger.go:293: sshd inside container not required for job, skipping setup.
# 2020/08/28 20:36:17 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-08-28T20:36:26Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/08/28 20:34:41 setuptask.go:353: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/28 20:34:41 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# >>>   2020/08/28 20:34:41 dynamicconfigs.go:17: Reading dyanamic configs
# >>>   2020/08/28 20:34:41 selfupdate.go:181: Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D
# >>>   2020/08/28 20:34:41 logger.go:293: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/28 20:34:41 logger.go:293: azsecpack isEnable:false
# >>>   2020/08/28 20:34:41 logger.go:293: DetonationChamber is not enabled on this subscription: 7c9d382c-5964-48db-9cf6-c595c7ba4339
# >>>   2020/08/28 20:34:41 logger.go:293: GPU count found: 0
# >>>   2020/08/28 20:34:41 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config
# >>>   2020/08/28 20:34:41 logger.go:293: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/28 20:34:41 logger.go:293: Starting identity responder.
# >>>   2020/08/28 20:34:41 userlogger.go:50: Starting identity responder.
# >>>   2020/08/28 20:34:41 utils.go:314: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/08/28 20:34:41 logger.go:293: Logfile used for identity responder: /mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/IdentityResponderLog-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:34:41 userlogger.go:50: Logfile used for identity responder: /mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/IdentityResponderLog-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:34:41 logger.go:293: Started Identity Responder for job.
# >>>   2020/08/28 20:34:41 userlogger.go:50: Started Identity Responder for job.
# >>>   2020/08/28 20:34:41 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/wd
# >>>   2020/08/28 20:34:41 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/shared
# >>>   2020/08/28 20:34:41 logger.go:293: Mounting job level file systems
# >>>   2020/08/28 20:34:41 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts
# >>>   2020/08/28 20:34:41 protocol.go:762: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config/.amlcompute.datastorecredentials
# >>>   2020/08/28 20:34:41 protocol.go:764: Datastore credentials file not found, skipping.
# >>>   2020/08/28 20:34:41 protocol.go:731: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config/.master.runtimesastokens
# >>>   2020/08/28 20:34:41 protocol.go:733: Runtime sas tokens file not found, skipping.
# >>>   2020/08/28 20:34:41 logger.go:293: No NFS configured
# >>>   2020/08/28 20:34:41 logger.go:293: No Azure File Shares configured
# >>>   2020/08/28 20:34:41 logger.go:293: Mounting blob file systems
# >>>   2020/08/28 20:34:41 logger.go:293: Start to pulling docker image: f3a8797ad922485389fee8fb528d6fce.azurecr.io/azureml/azureml_30cd9c75f2bacedf66a964559d217bc8
# >>>   2020/08/28 20:34:41 logger.go:293: Requesting XDS for registry details.
# >>>   2020/08/28 20:34:41 logger.go:293: Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/7c9d382c-5964-48db-9cf6-c595c7ba4339/resourceGroups/mlops-rg/workspaces/mlops-aml/clusters/mlops-cc/nodes/tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d?api-version=2018-02-01
# >>>   2020/08/28 20:34:41 logger.go:293: Mounting azureml-blobstore-f3a8797a-d922-4853-89fe-e8fb528d6fce container from mlopsaml4162067231 account at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore
# >>>   2020/08/28 20:34:41 logger.go:293: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/28 20:34:41 logger.go:293: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/28 20:34:41 userlogger.go:50: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/28 20:34:41 userlogger.go:50: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore
# >>>   2020/08/28 20:34:41 logger.go:293: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore
# >>>   2020/08/28 20:34:42 logger.go:293: Successfully mounted azureml-blobstore-f3a8797a-d922-4853-89fe-e8fb528d6fce container from mlopsaml4162067231 account at /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore
# >>>   2020/08/28 20:34:42 logger.go:293: No unmanaged file systems configured
# >>>   2020/08/28 20:34:42 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs
# >>>   2020/08/28 20:34:44 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/logs
# >>>   2020/08/28 20:34:44 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/outputs
# >>>   2020/08/28 20:34:44 userlogger.go:50: Starting output-watcher...
# >>>   2020/08/28 20:34:45 logger.go:293: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/08/28 20:34:45 logger.go:293: Got container registry details from credentials service.
# >>>   2020/08/28 20:34:45 logger.go:293: Writing ACR Details to file...
# >>>   2020/08/28 20:34:45 logger.go:293: Copying ACR Details file to worker nodes...
# >>>   2020/08/28 20:34:45 userlogger.go:50: Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2020/08/28 20:34:45 userlogger.go:50: Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/08/28 20:36:06 logger.go:293: Pull docker image time: 1m24.411115327s
# >>>
# >>>   2020/08/28 20:36:06 logger.go:293: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/08/28 20:36:06 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/08/28 20:36:06 logger.go:293: Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name c4ad3808-73c9-431d-b90d-99cf99e66e67 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/certs:/mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67:/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67 -v /mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/wd:/mnt/batch/tasks/workitems/875496bf-b21c-4ebc-b367-217a8f68cb3e/job-1/c4ad3808-73c9-431d-b_39362135-7f3e-4527-b97f-edc29abb5d42/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host f3a8797ad922485389fee8fb528d6fce.azurecr.io/azureml/azureml_30cd9c75f2bacedf66a964559d217bc8
# >>>   2020/08/28 20:36:17 logger.go:293: Container ssh is not required for job type.
# >>>   2020/08/28 20:36:17 logger.go:293: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs
# >>>   2020/08/28 20:36:17 logger.go:293: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python $AZ_BATCHAI_INPUT_AZUREML/c4ad3808-73c9-431d-b90d-99cf99e66e67-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e93131c5-1607-4077-8969-97d88b80c7fa","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/28 20:36:17 logger.go:293: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs/65_job_prep-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:36:17 logger.go:293: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml_compute_logs/65_job_prep-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:36:17 logger.go:293: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67;/azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e93131c5-1607-4077-8969-97d88b80c7fa","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/28 20:36:17 logger.go:293: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t c4ad3808-73c9-431d-b90d-99cf99e66e67 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67;/azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"e93131c5-1607-4077-8969-97d88b80c7fa","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:18.307831] Entering job preparation.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.018090] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.018133] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.019697] Starting job preparation.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.019725] Extracting the control code.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.055378] fetching and extracting the control code on master node.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.055415] Starting extract_project.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.055459] Starting to extract zip file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:19.884196] Finished extracting zip file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:20.092535] Using urllib.request Python 3.0 or later
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:20.092599] Start fetching snapshots.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:20.092638] Start fetching snapshot.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:20.092650] Retrieving project from snapshot: e93131c5-1607-4077-8969-97d88b80c7fa
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:20.093530] Start RetrieveProjectSasUrls
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.306396] Finished RetrieveProjectSasUrls
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.306477] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.306498] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.307804] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.307843] Starting project file download.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.379903] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.380051] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.425302] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.425334] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.425349] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.425365] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.442020] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.442056] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.442095] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.442502] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.471795] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.471826] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.471844] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.471860] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.489615] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.489646] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.489679] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.490040] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.536402] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.536433] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.536455] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.536475] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.609143] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.609190] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.609231] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.609753] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.684378] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.684418] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.684436] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:21.684452] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.390723] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.390846] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.390898] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.391650] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.414613] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.414671] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.414690] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.414706] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.479391] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.479432] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.479475] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.479947] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.519568] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.519599] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.519612] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.519631] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.540857] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.540888] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.541029] Starting _download_tree for file.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.541595] _download_tree start request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.570548] _download_tree finished request for file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.570576] _download_tree start writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.570640] TimeoutHandler __init__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.570661] TimeoutHandler __enter__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587078] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587104] _download_tree finished writing file
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587130] Finished project file download.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587158] Finished fetching snapshot.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587174] Finished fetching snapshots.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.587184] Finished extract_project.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.604120] Finished fetching and extracting the control code.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.607018] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.607967] Start run_history_prep.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:24.666713] Entering context manager injector.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: Acquired lockfile /tmp/c4ad3808-73c9-431d-b90d-99cf99e66e67-datastore.lock to downloading input data references
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:26.167018] downloadDataStore completed
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:26.170612] Job preparation is complete.
# >>>   2020/08/28 20:36:26 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:36:26.170914] TimeoutHandler __exit__
# >>>   2020/08/28 20:36:26 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/08/28 20:36:26 logger.go:293: Process Exiting with Code:  0
# >>>
# 2020-08-28T20:36:26Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-28T20:36:26Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-08-28T20:36:27.520425] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['driver_training.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 107
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67
# Preparing to call script [ driver_training.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/model_folder']
# After variable expansion, calling script [ driver_training.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/mounts/workspaceblobstore/azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/model_folder']
#
# Script type = None
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [1]	valid_0's auc: 0.595844
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's auc: 0.605252
# [3]	valid_0's auc: 0.612784
# [4]	valid_0's auc: 0.61756
# [5]	valid_0's auc: 0.620129
# [6]	valid_0's auc: 0.622447
# [7]	valid_0's auc: 0.622163
# [8]	valid_0's auc: 0.622112
# [9]	valid_0's auc: 0.622581
# [10]	valid_0's auc: 0.622278
# [11]	valid_0's auc: 0.622433
# [12]	valid_0's auc: 0.623423
# [13]	valid_0's auc: 0.623618
# [14]	valid_0's auc: 0.62414
# [15]	valid_0's auc: 0.624421
# [16]	valid_0's auc: 0.624512
# [17]	valid_0's auc: 0.625151
# [18]	valid_0's auc: 0.62529
# [19]	valid_0's auc: 0.625437
# [20]	valid_0's auc: 0.62563
# [21]	valid_0's auc: 0.625963
# [22]	valid_0's auc: 0.626147
# [23]	valid_0's auc: 0.626383
# [24]	valid_0's auc: 0.626618
# [25]	valid_0's auc: 0.626586
# [26]	valid_0's auc: 0.626839
# [27]	valid_0's auc: 0.626972
# [28]	valid_0's auc: 0.626935
# [29]	valid_0's auc: 0.626946
# [30]	valid_0's auc: 0.627204
# [31]	valid_0's auc: 0.627252
# [32]	valid_0's auc: 0.627302
# [33]	valid_0's auc: 0.627249
# [34]	valid_0's auc: 0.627517
# [35]	valid_0's auc: 0.627755
# [36]	valid_0's auc: 0.62766
# [37]	valid_0's auc: 0.627483
# [38]	valid_0's auc: 0.627578
# [39]	valid_0's auc: 0.627433
# [40]	valid_0's auc: 0.627573
# [41]	valid_0's auc: 0.627908
# [42]	valid_0's auc: 0.627968
# [43]	valid_0's auc: 0.628082
# [44]	valid_0's auc: 0.628398
# [45]	valid_0's auc: 0.628763
# [46]	valid_0's auc: 0.629011
# [47]	valid_0's auc: 0.629321
# [48]	valid_0's auc: 0.629341
# [49]	valid_0's auc: 0.629353
# [50]	valid_0's auc: 0.629291
# [51]	valid_0's auc: 0.629447
# [52]	valid_0's auc: 0.629507
# [53]	valid_0's auc: 0.629725
# [54]	valid_0's auc: 0.630048
# [55]	valid_0's auc: 0.630085
# [56]	valid_0's auc: 0.630035
# [57]	valid_0's auc: 0.630236
# [58]	valid_0's auc: 0.630486
# [59]	valid_0's auc: 0.630663
# [60]	valid_0's auc: 0.630787
# [61]	valid_0's auc: 0.630932
# [62]	valid_0's auc: 0.631004
# [63]	valid_0's auc: 0.631161
# [64]	valid_0's auc: 0.631407
# [65]	valid_0's auc: 0.631408
# [66]	valid_0's auc: 0.631515
# [67]	valid_0's auc: 0.631631
# [68]	valid_0's auc: 0.631628
# [69]	valid_0's auc: 0.631703
# [70]	valid_0's auc: 0.631781
# [71]	valid_0's auc: 0.631786
# [72]	valid_0's auc: 0.631779
# [73]	valid_0's auc: 0.632022
# [74]	valid_0's auc: 0.632086
# [75]	valid_0's auc: 0.632107
# [76]	valid_0's auc: 0.632201
# [77]	valid_0's auc: 0.632165
# [78]	valid_0's auc: 0.632335
# [79]	valid_0's auc: 0.632446
# [80]	valid_0's auc: 0.63254
# [81]	valid_0's auc: 0.632654
# [82]	valid_0's auc: 0.632663
# [83]	valid_0's auc: 0.632811
# [84]	valid_0's auc: 0.63291
# [85]	valid_0's auc: 0.632993
# [86]	valid_0's auc: 0.632962
# [87]	valid_0's auc: 0.632941
# [88]	valid_0's auc: 0.633062
# [89]	valid_0's auc: 0.633144
# [90]	valid_0's auc: 0.633242
# [91]	valid_0's auc: 0.633336
# [92]	valid_0's auc: 0.633453
# [93]	valid_0's auc: 0.633556
# [94]	valid_0's auc: 0.633648
# [95]	valid_0's auc: 0.633762
# [96]	valid_0's auc: 0.633831
# [97]	valid_0's auc: 0.633922
# [98]	valid_0's auc: 0.633908
# [99]	valid_0's auc: 0.633958
# [100]	valid_0's auc: 0.634122
# [101]	valid_0's auc: 0.634278
# [102]	valid_0's auc: 0.634301
# [103]	valid_0's auc: 0.634313
# [104]	valid_0's auc: 0.634366
# [105]	valid_0's auc: 0.634497
# [106]	valid_0's auc: 0.634442
# [107]	valid_0's auc: 0.634487
# [108]	valid_0's auc: 0.634578
# [109]	valid_0's auc: 0.634676
# [110]	valid_0's auc: 0.63479
# [111]	valid_0's auc: 0.634846
# [112]	valid_0's auc: 0.634918
# [113]	valid_0's auc: 0.63501
# [114]	valid_0's auc: 0.634965
# [115]	valid_0's auc: 0.635029
# [116]	valid_0's auc: 0.635077
# [117]	valid_0's auc: 0.635075
# [118]	valid_0's auc: 0.6352
# [119]	valid_0's auc: 0.635215
# [120]	valid_0's auc: 0.635231
# [121]	valid_0's auc: 0.635276
# [122]	valid_0's auc: 0.635268
# [123]	valid_0's auc: 0.635221
# [124]	valid_0's auc: 0.635178
# [125]	valid_0's auc: 0.635221
# [126]	valid_0's auc: 0.635288
# [127]	valid_0's auc: 0.635345
# [128]	valid_0's auc: 0.635348
# [129]	valid_0's auc: 0.635414
# [130]	valid_0's auc: 0.635418
# [131]	valid_0's auc: 0.635352
# [132]	valid_0's auc: 0.635402
# [133]	valid_0's auc: 0.635497
# [134]	valid_0's auc: 0.635545
# [135]	valid_0's auc: 0.63565
# [136]	valid_0's auc: 0.635622
# [137]	valid_0's auc: 0.635664
# [138]	valid_0's auc: 0.635781
# [139]	valid_0's auc: 0.635735
# [140]	valid_0's auc: 0.635719
# [141]	valid_0's auc: 0.635815
# [142]	valid_0's auc: 0.635799
# [143]	valid_0's auc: 0.63583
# [144]	valid_0's auc: 0.635898
# [145]	valid_0's auc: 0.635924
# [146]	valid_0's auc: 0.635885
# [147]	valid_0's auc: 0.635919
# [148]	valid_0's auc: 0.63598
# [149]	valid_0's auc: 0.636035
# [150]	valid_0's auc: 0.636087
# [151]	valid_0's auc: 0.636139
# [152]	valid_0's auc: 0.63617
# [153]	valid_0's auc: 0.636128
# [154]	valid_0's auc: 0.636096
# [155]	valid_0's auc: 0.636206
# [156]	valid_0's auc: 0.636259
# [157]	valid_0's auc: 0.636289
# [158]	valid_0's auc: 0.636283
# [159]	valid_0's auc: 0.636287
# [160]	valid_0's auc: 0.636293
# [161]	valid_0's auc: 0.636324
# [162]	valid_0's auc: 0.63633
# [163]	valid_0's auc: 0.636367
# [164]	valid_0's auc: 0.636438
# [165]	valid_0's auc: 0.636483
# [166]	valid_0's auc: 0.636577
# [167]	valid_0's auc: 0.636645
# [168]	valid_0's auc: 0.63659
# [169]	valid_0's auc: 0.636595
# [170]	valid_0's auc: 0.636672
# [171]	valid_0's auc: 0.636719
# [172]	valid_0's auc: 0.636755
# [173]	valid_0's auc: 0.636833
# [174]	valid_0's auc: 0.636908
# [175]	valid_0's auc: 0.636929
# [176]	valid_0's auc: 0.636928
# [177]	valid_0's auc: 0.636962
# [178]	valid_0's auc: 0.636969
# [179]	valid_0's auc: 0.636995
# [180]	valid_0's auc: 0.637059
# [181]	valid_0's auc: 0.637089
# [182]	valid_0's auc: 0.637085
# [183]	valid_0's auc: 0.637121
# [184]	valid_0's auc: 0.637131
# [185]	valid_0's auc: 0.637133
# [186]	valid_0's auc: 0.637144
# [187]	valid_0's auc: 0.637189
# [188]	valid_0's auc: 0.637173
# [189]	valid_0's auc: 0.63719
# [190]	valid_0's auc: 0.637205
# [191]	valid_0's auc: 0.637131
# [192]	valid_0's auc: 0.637159
# [193]	valid_0's auc: 0.637185
# [194]	valid_0's auc: 0.63719
# [195]	valid_0's auc: 0.637224
# [196]	valid_0's auc: 0.637219
# [197]	valid_0's auc: 0.637193
# [198]	valid_0's auc: 0.637297
# [199]	valid_0's auc: 0.637329
# [200]	valid_0's auc: 0.6373
# [201]	valid_0's auc: 0.637257
# [202]	valid_0's auc: 0.637253
# [203]	valid_0's auc: 0.637261
# [204]	valid_0's auc: 0.637252
# [205]	valid_0's auc: 0.637273
# [206]	valid_0's auc: 0.637297
# [207]	valid_0's auc: 0.637345
# [208]	valid_0's auc: 0.637401
# [209]	valid_0's auc: 0.637456
# [210]	valid_0's auc: 0.637392
# [211]	valid_0's auc: 0.637373
# [212]	valid_0's auc: 0.63741
# [213]	valid_0's auc: 0.637459
# [214]	valid_0's auc: 0.637496
# [215]	valid_0's auc: 0.637539
# [216]	valid_0's auc: 0.637546
#
# Streaming azureml-logs/75_job_post-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-28T20:37:08.160781
# Starting job release. Current time:2020-08-28T20:37:09.261446
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 180
# [2020-08-28T20:37:09.271749] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-08-28T20:37:09.274139] job release stage : execute_job_release starting...
# [2020-08-28T20:37:09.281407] job release stage : copy_batchai_cached_logs starting...
# [2020-08-28T20:37:09.281451] job release stage : copy_batchai_cached_logs completed...
# [2020-08-28T20:37:09.282259] Entering context manager injector.
# [2020-08-28T20:37:09.606666] job release stage : upload_datastore completed...
# [2020-08-28T20:37:09.813350] job release stage : send_run_telemetry starting...
# [2020-08-28T20:37:09.878021] job release stage : execute_job_release completed...
# [2020-08-28T20:37:10.176225] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-08-28T20:37:10.176328
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'c4ad3808-73c9-431d-b90d-99cf99e66e67', 'target': 'mlops-cc', 'status': 'Completed', 'startTimeUtc': '2020-08-28T20:34:38.737939Z', 'endTimeUtc': '2020-08-28T20:37:15.49623Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'e93131c5-1607-4077-8969-97d88b80c7fa', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '26dc8131-f09f-4352-a1f4-178976a9b395', 'azureml.pipelinerunid': 'c25e809f-4b13-43b4-ac4e-2fad95ecbf79', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '29a50f1f-06b4-4ae6-a587-33995d51a5a4'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'driver_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'driver_training.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mlops-cc', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'driver_train': {'dataLocation': {'dataset': {'id': '29a50f1f-06b4-4ae6-a587-33995d51a5a4', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'driver_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'driver-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas', 'lightgbm'], 'name': 'azureml_084dd3e553b36e7441647d5cfd78aa61'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ad3808-73c9-431d-b90d-99cf99e66e67/azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt?sv=2019-02-02&sr=b&sig=OngmaSK9jlOihMBXGriMAyS4BvHDndhs9QooIeaP0RE%3D&st=2020-08-28T20%3A27%3A12Z&se=2020-08-29T04%3A37%3A12Z&sp=r', 'azureml-logs/65_job_prep-tvmps_7280843 ...
#
#
#
#
# StepRunId: b4488948-8717-41e9-a2db-b4c03b255a0e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/b4488948-8717-41e9-a2db-b4c03b255a0e?wsid=/subscriptions/7c9d382c-5964-48db-9cf6-c595c7ba4339/resourcegroups/mlops-rg/workspaces/mlops-aml
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# ========================================================================================================================
# 2020-08-28T20:37:56Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-08-28T20:37:56Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2020-08-28T20:37:56Z Starting output-watcher...
# 2020-08-28T20:37:56Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_30cd9c75f2bacedf66a964559d217bc8
# Digest: sha256:87695151d6316cd952b7e7698fbf52e744815249da724ceb53bc83ae049f7416
# Status: Image is up to date for f3a8797ad922485389fee8fb528d6fce.azurecr.io/azureml/azureml_30cd9c75f2bacedf66a964559d217bc8:latest
# 964de563fb20accc71fb54b81ff8c7c32db7cc7b1280443da24f6234aced748f
# 2020/08/28 20:37:58 setuptask.go:353: Starting App Insight Logger for task:  containerSetup
# 2020/08/28 20:37:58 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# 2020/08/28 20:37:58 utils.go:302: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/28 20:37:58 logger.go:293: sshd inside container not required for job, skipping setup.
# 2020/08/28 20:37:59 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-08-28T20:38:08Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/08/28 20:37:53 setuptask.go:353: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/28 20:37:53 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# >>>   2020/08/28 20:37:53 dynamicconfigs.go:17: Reading dyanamic configs
# >>>   2020/08/28 20:37:53 selfupdate.go:181: Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D
# >>>   2020/08/28 20:37:53 logger.go:293: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/28 20:37:53 logger.go:293: azsecpack isEnable:false
# >>>   2020/08/28 20:37:53 logger.go:293: DetonationChamber is not enabled on this subscription: 7c9d382c-5964-48db-9cf6-c595c7ba4339
# >>>   2020/08/28 20:37:53 logger.go:293: GPU count found: 0
# >>>   2020/08/28 20:37:53 logger.go:293: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/config
# >>>   2020/08/28 20:37:53 logger.go:293: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/28 20:37:53 logger.go:293: Starting identity responder.
# >>>   2020/08/28 20:37:53 userlogger.go:50: Starting identity responder.
# >>>   2020/08/28 20:37:53 utils.go:314: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/config/.batchai.IdentityResponder.envlist: no such file or directory
# ...
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.007175] TimeoutHandler __enter__
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.024865] TimeoutHandler __exit__
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.024922] _download_tree finished writing file
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.024959] Starting _download_tree for file.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.025302] _download_tree start request for file
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.046583] _download_tree finished request for file
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.046636] _download_tree start writing file
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.046652] TimeoutHandler __init__
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.046667] TimeoutHandler __enter__
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066581] TimeoutHandler __exit__
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066606] _download_tree finished writing file
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066632] Finished project file download.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066662] Finished fetching snapshot.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066671] Finished fetching snapshots.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.066677] Finished extract_project.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.095157] Finished fetching and extracting the control code.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.098978] Start run_history_prep.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.099180] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:06.166794] Entering context manager injector.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: Acquired lockfile /tmp/b4488948-8717-41e9-a2db-b4c03b255a0e-datastore.lock to downloading input data references
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:08.152780] downloadDataStore completed
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:08.155921] Job preparation is complete.
# >>>   2020/08/28 20:38:08 logger.go:293: runSpecialJobTask: preparation: [2020-08-28T20:38:08.156053] TimeoutHandler __exit__
# >>>   2020/08/28 20:38:08 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/08/28 20:38:08 logger.go:293: Process Exiting with Code:  0
# >>>
# 2020-08-28T20:38:08Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-28T20:38:09Z launching Custom job
# 2020-08-28T20:38:19Z job exited with code 0
# 2020-08-28T20:38:19Z Executing 'JobRelease task' on 10.0.0.5
# 2020-08-28T20:38:22Z JobRelease task succeeded on 10.0.0.5. Output:
# >>>   2020/08/28 20:38:19 setuptask.go:353: Starting App Insight Logger for task:  jobRelease
# >>>   2020/08/28 20:38:19 logger.go:293: Version: 3.0.01321.0003 Branch: .SourceBranch Commit: 8fd8782
# >>>   2020/08/28 20:38:19 logger.go:293: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml_compute_logs
# >>>   2020/08/28 20:38:19 logger.go:293: runSpecialJobTask: Raw cmd for postprocessing is passed is: /azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/08/28 20:38:19 logger.go:293: runSpecialJobTask: stdout path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml_compute_logs/75_job_post-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:38:19 logger.go:293: runSpecialJobTask: stderr path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml_compute_logs/75_job_post-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# >>>   2020/08/28 20:38:19 logger.go:293: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e;/azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/08/28 20:38:19 logger.go:293: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t b4488948-8717-41e9-a2db-b4c03b255a0e bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e;/azureml-envs/azureml_084dd3e553b36e7441647d5cfd78aa61/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mlops-aml/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/mounts/workspaceblobstore/azureml/b4488948-8717-41e9-a2db-b4c03b255a0e/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: job postprocessing exited with code 0 and err <nil>
# >>>
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: Entering job release. Current time:2020-08-28T20:38:20.037450
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: Starting job release. Current time:2020-08-28T20:38:21.212499
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: Logging experiment finalizing status in history service.
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: Starting the daemon thread to refresh tokens in background for process with pid = 155
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.229874] job release stage : upload_datastore starting...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.230177] job release stage : execute_job_release starting...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.232768] job release stage : copy_batchai_cached_logs starting...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.233233] job release stage : copy_batchai_cached_logs completed...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.240544] Entering context manager injector.
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.522568] job release stage : upload_datastore completed...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.602378] job release stage : send_run_telemetry starting...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.849226] job release stage : send_run_telemetry completed...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: [2020-08-28T20:38:21.894343] job release stage : execute_job_release completed...
# >>>   2020/08/28 20:38:22 logger.go:293: runSpecialJobTask: postprocessing: Job release is complete. Current time:2020-08-28T20:38:21.894542
# >>>   2020/08/28 20:38:22 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>
# 2020-08-28T20:38:22Z Executing 'Job environment clean-up' on 10.0.0.5
#
# Streaming azureml-logs/75_job_post-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-28T20:38:20.037450
# Starting job release. Current time:2020-08-28T20:38:21.212499
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 155
# [2020-08-28T20:38:21.229874] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-08-28T20:38:21.230177] job release stage : execute_job_release starting...
# [2020-08-28T20:38:21.232768] job release stage : copy_batchai_cached_logs starting...
# [2020-08-28T20:38:21.233233] job release stage : copy_batchai_cached_logs completed...
# [2020-08-28T20:38:21.240544] Entering context manager injector.
# [2020-08-28T20:38:21.522568] job release stage : upload_datastore completed...
# [2020-08-28T20:38:21.602378] job release stage : send_run_telemetry starting...
# [2020-08-28T20:38:21.849226] job release stage : send_run_telemetry completed...
# [2020-08-28T20:38:21.894343] job release stage : execute_job_release completed...
# Job release is complete. Current time:2020-08-28T20:38:21.894542
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': 'b4488948-8717-41e9-a2db-b4c03b255a0e', 'target': 'mlops-cc', 'status': 'Completed', 'startTimeUtc': '2020-08-28T20:37:55.956318Z', 'endTimeUtc': '2020-08-28T20:38:29.836009Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'e93131c5-1607-4077-8969-97d88b80c7fa', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a7575e1b-ceb9-4d54-9fad-5bd20798b744', 'azureml.pipelinerunid': 'c25e809f-4b13-43b4-ac4e-2fad95ecbf79', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mlops-cc', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/c4ad3808-73c9-431d-b90d-99cf99e66e67/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'driver-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas', 'lightgbm'], 'name': 'azureml_084dd3e553b36e7441647d5cfd78aa61'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.b4488948-8717-41e9-a2db-b4c03b255a0e/azureml-logs/55_azureml-execution-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt?sv=2019-02-02&sr=b&sig=o8huw1DEiY0XSK%2FZ%2FyxDnDJtTk6N%2FJA02hTREfVwnL4%3D&st=2020-08-28T20%3A28%3A25Z&se=2020-08-29T04%3A38%3A25Z&sp=r', 'azureml-logs/65_job_prep-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.b4488948-8717-41e9-a2db-b4c03b255a0e/azureml-logs/65_job_prep-tvmps_7280843b9e78192e8b364f97e8aab2dc43d3012c6912dd61885459426b71b3fc_d.txt?sv=2019-02-02&sr=b&sig=kKIo8JUt0E72LeRsATv7QWF0jyy%2F9GhdqIIa84MrF%2Fs%3D&st=2020-08-28T20%3A28%3A25Z&se=2020-08-29T04 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c25e809f-4b13-43b4-ac4e-2fad95ecbf79', 'status': 'Completed', 'startTimeUtc': '2020-08-28T20:30:21.283272Z', 'endTimeUtc': '2020-08-28T20:38:35.57925Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.c25e809f-4b13-43b4-ac4e-2fad95ecbf79/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=%2FHXyZ1bjLPYQFb6Gx61gWwkrmu8eeQ1CDglQ1wchhvI%3D&st=2020-08-28T20%3A28%3A36Z&se=2020-08-29T04%3A38%3A36Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.c25e809f-4b13-43b4-ac4e-2fad95ecbf79/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=izJWOW%2FhYkc640%2BxzZL%2BKVi1KEoUyj7PfW6lsQqkl50%3D&st=2020-08-28T20%3A28%3A36Z&se=2020-08-29T04%3A38%3A36Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlopsaml4162067231.blob.core.windows.net/azureml/ExperimentRun/dcid.c25e809f-4b13-43b4-ac4e-2fad95ecbf79/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=BlfW%2BDew0XCYs2Jcq77eCBc8ImpYMp4FuwvSfhnlx7M%3D&st=2020-08-28T20%3A28%3A36Z&se=2020-08-29T04%3A38%3A36Z&sp=r'}}
# 'Finished'

# %%
# Print the model name, version, tag, and properties
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# porto_seguro_safe_driver_model version: 3
# 	 learning_rate : 0.02
# 	 boosting_type : gbdt
# 	 objective : binary
# 	 metric : auc
# 	 sub_feature : 0.7
# 	 num_leaves : 60
# 	 min_data : 100
# 	 min_hessian : 1
# 	 verbose : 0
# 	 auc : 0.6377511613946426
#
#
# driver_model.pkl version: 2
# 	 auc : 0.6377511613946426
#
#
# porto_seguro_safe_driver_model version: 2
# 	 learning_rate : 0.02
# 	 boosting_type : gbdt
# 	 metric : auc
# 	 objective : binary
# 	 sub_feature : 0.7
# 	 min_data : 100
# 	 num_leaves : 60
# 	 min_hessian : 1
# 	 verbose : 0
# 	 auc : 0.6377511613946426
#
#
# porto_seguro_safe_driver_model version: 1
#
#
# driver_model.pkl version: 1
# 	 auc : 0.6377511613946426
